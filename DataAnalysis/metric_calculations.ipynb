# %% [markdown]
# ## Overview
# This script performs various metric calculations on the partipant session's data to describe and summarize it.
#
# ### Output Details
# For each code block, a total of 26 files are exported: two for each gesture, representing either freeform or instructional data. These files include data from the first five trials of each participant session. Each row corresponds to data from an individual stroke or trial. A blank row is used to separate different participant sessions. Additionally, there are two columns that represent the left and right controllers.
#
# ### Metric Calculation
#     * Length (Code block 5)
#     * Duration (Code block 6)
#     * Speed (Code block 7)
#     * Acceleration (Code block 8)
#     * Angle (Code block 9)
#     * Curvature (Code block 10)
#
# ### Folder Directory
# To simplify the file exports, making the following folders for the output metric calculations:
#     * GestureAcceleration
#     * GestureAngle
#     * GestureCurvature
#     * GestureDuration
#     * GestureLength
#     * GestureSpeed
#
# ### To Do
# Run code blocks in order
# * Create folders in the directory
# * Import libraries (#1)
# * Generate gesture dictionary with file paths to the data (#2)
# * Define mutual functions for metric calculations (#3)
# * Helper methods to remove certain strokes and extremities from calculations (#4)
# * Functions for metric calculation (#5 - #10)
# * Functions to iterate through data files and run the calculations (#11)
# * Run the methods here (#12)
#
# Read the markdowns to ensure that edits have been made.

# %%
import math
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
from scipy.interpolate import BSpline, make_interp_spline
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Overview #2
# Processes a data directory and organizes it into a dictionary for efficient iteration when creating box plots. Instead of iterating by subject ID in the CleanedData directory, this structure iterates directly by gesture.
#
# ### Dictionary
# * 12 Keys: Each key represents one of the 12 different gestures.
# * Values: Each key contains a list with two sublists:
#     * First sublist: Paths to all CSV files for freeform sessions except subject 1.
#     * Second sublist: Paths to all CSV files for instructional sessions except subject 1.
#
# ### Variables
# * cleaned_data_folder_path: Path to folder with all the cleaned data.
#     * Ensure that your CleanedData directory contains Sub folders -> Session Type folders -> 13 data files for each gesture. Should have this from running export_clean_files.py
#
# ### To Do
# * Edit variables

# %%
''' Edit variable here'''
cleaned_data_folder_path = '..\\VRelax\\gestureInterface\\CleanedData'

gesture_dict = {}

# Iterate through CleanedData directory to create a dictionary of gestures
# Each of the 12 gesture has two lists (freeform and instructional) containing paths to CSV data files.
for root, sub_folders, files in os.walk(cleaned_data_folder_path):
    sub_folders.sort()
    files.sort()
    
    for file in files:
        # Splits file name for gesture and session type identification
        file_split = file.split("_") 
        file_gesture, file_session_type, subject_id = file_split[3], file_split[2], file_split[5]

        # Skip unnecessary files: Box Select or Subject 1
        if file_gesture == 'BoxSelect' or subject_id == '1':
            continue

        # Skip the thank you/non-session files
        if file_session_type not in {'F', 'I'}:
            continue

        # Initialize gesture key in the dictionary if not already present
        if file_gesture not in gesture_dict:
            gesture_dict[file_gesture] = ([], [])  # [freeform_list, instructional_list]

        # Append file path to the appropriate session list
        if file_session_type == 'F':
            gesture_dict[file_gesture][0].append(os.path.join(root, file))
        else:
            gesture_dict[file_gesture][1].append(os.path.join(root, file))

# %% [markdown]
# ### Overview #3
# Methods that all of the metric calculations will need to use.
#
# ### Functions
# * get_column_name - Gets the name for a column. Consists of gesture and session type.
# * get_gest_export_path - Gets export path for a single gesture session file.

# %%
def get_gest_export_path(metric_folder_path, file_path, gesture, metric_name):
    """
    Gets the export path for the metric calculations.

    Parameters
    -----
    metric_folder_path : str
        Path to the metric folder to export to.
    file_path : str
        Path to the original CSV data file.
    gesture : str
        A gesture key in the gesture_dict variable in code block 2.
    metric_name : str
        Name of the quantitative measurement.

    Returns
    -----
    output_path : str
        The output path where the boxplot data file will be exported.
    """

    # Identify session type based on the original file path.
    session = "Freeform" if os.path.basename(file_path).split("_")[2] == 'F' else "Instructional"

    # Construct gesture part of the file name in snake_case.
    gesture_snake_case = ''.join(['_' + c.lower() if c.isupper() else c for c in gesture]).lstrip('_')

    # Create the final output path.
    output_path = os.path.join(metric_folder_path, f"{metric_name}_for_{gesture_snake_case}_{session.lower()}.csv")

    return output_path


def get_column_name(file_path, gesture):
    """
    Gets the name for a column in the boxplot data file, which contains the gesture and session type.

    Parameters
    -----
    file_path : str
        Path to the original CSV data file.
    gesture : str
        A gesture key in the gesture_dict variable in code block 2.

    Returns
    -----
    column_name : str
        Name of the column based on gesture and session type.
    """

    # Identify session type based on the original file path.
    session = "Freeform" if os.path.basename(file_path).split("_")[2] == 'F' else "Instructional"

    # Construct gesture name with spaces before each uppercase letter (except the first).
    gesture_name = ''.join([' ' + c if c.isupper() and i != 0 else c for i, c in enumerate(gesture)])

    # Create the final column name. Ex) Pan Left Freeform
    column_name = f"{gesture_name} {session}"

    return column_name

# %% [markdown]
# ### Overview #4
# The methods outlined below are used to preprocess the data before calculating external angles and curvature. It cleans the data by removing factors (hooks or accidents) that could distort the final results.
#
# ### Functions
# * disect_cell: Determines which strokes to be removed based on cell value in the stroke removal file.
# * remove_strokes: Remove unwanted strokes, such as accidental strokes or small dots, that were unintentionally created.
# * remove_extremities: Accounts for extremities or "hooks". These hooks refer to sharp curves typically formed at the start or end of a gesture, where participants often create abrupt movements after pulling or just before releasing the triggers. The function below utilizes the median absolute deviation (MAD) to detect and handle these extremities.
#
# ### Variables
# * df_for_stroke_removal: path to the stroke removal csv file.
#
# ### To do
# * Edit variables

# %%
'''Edit variable here'''
df_for_stroke_removal = pd.read_csv('..\\gestureInterface\\MetricCalculations\\strokes_to_remove.csv')


def disect_cell(input):
    """
    Determines which strokes to remove based on cell value in the stroke removal file.

    Parameters
    -----
    input : str
        value in cell. Has the format of [3:5], [2], or [4:] where the number indicates the stroke and ':' indicates a range.

    Returns
    -----
    list_strokes_to_remove : str
        list of strokes to remove
    """

    i, list_strokes_to_remove = 0, []
    while i < len(input):
        if input[i] == '[':
            i += 1
            # Indicates a range of strokes to be removed
            if input[i+1] == ':':
                for j in range(int(input[i]), int(input[i+2])+1):
                    list_strokes_to_remove.append(j)
                i += 1
            # A single stroke is to be removed
            else:
                list_strokes_to_remove.append(int(input[i]))
                i += 1
        else:
            i += 1

    return list_strokes_to_remove


def remove_strokes(df, gesture_key_index, row_index):
    """
    Removes strokes by setting trigger pulls in that trial to 0.

    Parameters
    -----
    df : dataframe
        dataframe for a single sub session data file such as sub 6 session 3.
    gesture_key_index : int
        index of the gesture, which will be used to access the correct column in the stroke removal file.
    row_index : int
        index of the row that indicates which subject session. Will be used to access the correct row in the stroke removal file.
    """

    l_col_index, r_col_index = gesture_key_index * 2 + 1, gesture_key_index * 2 + 2
    value_in_left_cell = df_for_stroke_removal.iloc[row_index, l_col_index]
    value_in_right_cell = df_for_stroke_removal.iloc[row_index, r_col_index]

    # Determine which strokes to remove in that list
    l_strokes_to_remove = disect_cell(value_in_left_cell) if pd.notna(value_in_left_cell) else []
    r_strokes_to_remove = disect_cell(value_in_right_cell) if pd.notna(value_in_right_cell) else []


    # Change original df's trigger_pull_amount to 0 where strokes are to be removed
    for stroke_num in l_strokes_to_remove:
        df.loc[df['gesture_counter_UI'] == stroke_num, 'trigger_pull_amount_left'] = 0
    for stroke_num in r_strokes_to_remove:
        df.loc[df['gesture_counter_UI'] == stroke_num, 'trigger_pull_amount_right'] = 0


def remove_extremities(values):
    """
    Removes extremities in the metric calculations using median absolute deviation, such as hooks at the ends of strokes.

    Parameters
    -----
    values : list
        list of metric calculation values to be altered
    """

    threshold = 2
    median = np.median(values)
    mad = np.median([abs(x - median) for x in values])
    
    # Calculate the modified Z-scores
    modified_z_scores = [0.6745 * (x - median) / mad if mad != 0 else 0 for x in values]
    
    # Return a new list with outliers removed
    cleaned_values = [values[i] for i in range(len(values)) if abs(modified_z_scores[i]) <= threshold]
    return cleaned_values

# %% [markdown]
# ### Overview #5
# Methods to help find the length of a gesture's trial.
#
# ### Functions
# * calculate_length: Gets the distance between two points in space.
# * get_stroke_length: Gets the total length of a single trial.

# %%
def calculate_length(pt1, pt2):
    """
    Calculates the Euclidean distance between two points in 3D space.

    Parameters
    ----------
        pt1 : tuple
            A tuple of three floats representing the (x, y, z) coordinates of the first point.
        pt2 : tuple
            A tuple of three floats representing the (x, y, z) coordinates of the second point.

    Returns:
    --------
        distance : float
            The Euclidean distance between the two points.
    """

    return math.dist(pt1, pt2)


def get_stroke_length(df, trial_num, hand):
    """
    Calculates the length of a gesture trial by summing the distances between sequential points.

    Parameters
    -----
    df : DataFrame
        DataFrame containing gesture data.
    trial_num : int
        The trial number (gesture counter UI) to analyze.
    hand : str
        Specifies 'l' for left or 'r' for right hand controller.

    Returns
    -----
    length_sum : float
        The total length of the trial based on the sum of distances between consecutive points.
    """

    # Filter DataFrame for the specified trial number and non-zero trigger pull
    trigger_col = f"trigger_pull_amount_{'left' if hand == 'l' else 'right'}"
    condition = (df[trigger_col] != 0) & (df['gesture_counter_UI'] == trial_num)
    filtered_df = df[condition].reset_index(drop=True)

    # Extract translation columns
    x_col = filtered_df[f"{hand}_controller_translation_x"].astype(float)
    y_col = filtered_df[f"{hand}_controller_translation_y"].astype(float)
    z_col = filtered_df[f"{hand}_controller_translation_z"].astype(float)

    # Sum lengths between consecutive points
    length_sum = sum(
        calculate_length((x1, y1, z1), (x2, y2, z2))
        for (x1, y1, z1), (x2, y2, z2) in zip(zip(x_col[:-1], y_col[:-1], z_col[:-1]), zip(x_col[1:], y_col[1:], z_col[1:]))
        if not any(map(math.isnan, [x1, y1, z1, x2, y2, z2]))  # Skip NaN values
    )

    return length_sum if length_sum > 0 else np.nan

# %% [markdown]
# ### Overview #6
# Utility methods to calculate the duration of a gesture trial.
#
# ### Functions
# * calculate_time_difference: Calculates the time difference between the start and end of a gesture.
# * get_stroke_duration: Computes the total duration of a single trial.

# %%
def calculate_time_difference(start_time, end_time):
    """
    Finds the total duration of a specific trial, from the first trigger pull to the last trigger release.

    Parameters
    -----
    df : DataFrame
        DataFrame to analyze.
    trial_num : int
        The trial number to filter in the data.

    Returns
    -----
    duration : float
        The duration of the gesture in the specified trial.
    """
   
    return end_time - start_time


def get_stroke_duration(df, trial_num):
    """
    Finds the total time of a specific trial, which is when a controller trigger is first pulled up to when the last trigger is released.

    Parameters
    -----
    df : DataFrame
        DataFrame to analyze.
    trial_num : int
        The trial number to filter in the data.

    Returns
    -----
    duration : float
        The duration of the gesture in the specified trial.
    """
    # Filter rows where either trigger is pulled and matches the trial number
    filtered_df = df[(df["gesture_counter_UI"] == trial_num) & 
                     ((df["trigger_pull_amount_left"] != 0) | (df["trigger_pull_amount_right"] != 0))]
    
    # If no rows meet the criteria, return NaN
    if filtered_df.empty:
        return np.nan

    # Get start and end times for the gesture
    start_time = float(filtered_df.iloc[0]['time'])
    end_time = float(filtered_df.iloc[-1]['time'])

    # Calculate duration
    duration = calculate_time_difference(start_time, end_time)

    return duration if duration > 0 else np.nan

# %% [markdown]
# ### Overview #7
# Utility methods to find the speed of a gesture's trial.
#
# ### Functions
# * calculate_speed: Calculate the average speed of a stroke.

# %%
def calculate_speed(length, time):
    """
    Calculates the average speed of a stroke.

    Parameters
    -----
    length : float
        The total distance covered by the stroke.
    time : float
        The duration of the stroke from start to finish.

    Returns
    -----
    speed : float
        The average speed of the stroke (distance over time).
    """

    speed = np.nan
    if (time != 0):
        speed = length / time
    return speed

# %% [markdown]
# ### Overview #8
# Utility methods to find the acceleration of a gesture's trial.
#
# ### Functions
# * calculate_acceleration: Calculate the average acceleration of a stroke.

# %%
def calculate_acceleration(speed, time):
    """
    Finds the acceleration of a stroke.

    Parameters
    -----
    final_speed : float
        average speed of gesture
    final_time : float
        duration of the stroke from start to finish

    Returns
    -----
    acceleration : float
        rate at which the speed changes over time
    """

    acceleration = np.nan
    if (time != 0):
        acceleration = speed / time
    return acceleration

# %% [markdown]
# ### Overview #9
# Utility methods to find the average external angle of a stroke.
#
# ### Functions
# * calculate_angle: Gets the external angle created by three points in space.
# * get_stroke_angle: Gets average external curvature of a trial/stroke.

# %%
def calculate_angle(p1, p2, p3):
    """
    Finds the external angle of three points or 2 vectors.

    Parameters
    -----
    p1 : tuple
        point 1 with x, y, z coordinates
    p2 : tuple
        point 2 with x, y, z coordinates
    p3 : tuple
        point 3 with x, y, z coordinates

    Returns
    -----
    ext_angle : float
        external angle created by the three points
    """
    # Convert points to numpy arrays for easier vector operations
    p1, p2, p3 = np.array(p1), np.array(p2), np.array(p3)

    # Convert two points into a vector
    a_vector = np.linalg.norm(p2 - p1)
    b_vector = np.linalg.norm(p3 - p2)
    
    ext_angle = np.nan
    if (a_vector > 0.0) and (b_vector > 0.0):
        # Normalize vector a and b
        normalized_a = (p2-p1)/a_vector
        normalized_b = (p3-p2)/b_vector
        normalized_dot = np.dot(normalized_a, normalized_b)

        # Clamp dot product for floating-point safety
        normalized_dot = np.clip(normalized_dot, -1.0, 1.0)

        # Compute angle in degrees
        ext_angle = np.rad2deg(np.arccos(normalized_dot))

    return ext_angle


def get_stroke_angle(df, trial_num, hand):
    """
    Gets the angle of a single stroke/trial.
    
    Parameters
    -----
    df : dataframe
        file dataframe to analyze
    trial_num : int
        trial number or gesture counter UI to analyze
    hand : char
        left or right controller to analyze the position/translation

    Returns
    -----
    angle_avg : float
        the sum of all the external angles divided by the number of angles added to that sum
    """

    # Filter DataFrame for the specified trial number and non-zero trigger pull
    trigger_col = f"trigger_pull_amount_{'left' if hand == 'l' else 'right'}"
    condition = (df[trigger_col] != 0) & (df['gesture_counter_UI'] == trial_num)
    condition &= df[hand + "_controller_translation_x"].notna()
    filtered_df = df[condition].reset_index(drop=True)

    # Smooths the curve
    x = np.array(filtered_df[hand + '_controller_translation_x'])
    y = np.array(filtered_df[hand + '_controller_translation_y'])
    z = np.array(filtered_df[hand + '_controller_translation_z'])

    # The number of control points and knots
    k = 3  # degree of the B-spline
    t = np.linspace(0, 1, len(filtered_df))
    
    # Create the B-spline representation for each dimension
    # Condition checks that make_interp_spline will return valid values
    if (len(t) > 0) and (len(x) > 3):
        spl_x = make_interp_spline(t, x, k=k)
        spl_y = make_interp_spline(t, y, k=k)
        spl_z = make_interp_spline(t, z, k=k)
        # Evaluate the B-spline over a dense set of points for a smooth trajectory
        dense_t = np.linspace(0, 1, 5 * len(filtered_df))  # points in the smoothed curve; can be adjusted
        x_smooth = spl_x(dense_t)
        y_smooth = spl_y(dense_t)
        z_smooth = spl_z(dense_t)
        coordinates = list(zip(x_smooth, y_smooth, z_smooth))

        # Determine the new data points based on min distance
        n_points_desired = 10
        points_list = []
        min_points_distance = round(len(x_smooth) / (n_points_desired))
        for coordinate in coordinates[::min_points_distance]:
            points_list.append(coordinate)

        # Get a list of angles from points list
        angle_list = []
        for index in range(2, len(points_list)):
            angle_list.append(calculate_angle(points_list[index-2], points_list[index-1], points_list[index]))

        # Remove extreme angles
        angle_list = remove_extremities(angle_list)

        # Calculate avg angle
        return sum(angle_list)/len(angle_list)

# %% [markdown]
# ### Overview #10
# Utility methods to find the average curvature of a stroke.
#
# ### Functions
# * calculate_curvature: Gets the curvature created by three points in space.
# * get_stroke_curvature: Gets average curvature of a trial/stroke.

# %%
def calculate_curvature(p1, p2, p3):
    """
    Calculates the curvature at 3 data points.
    
    Parameters
    -----
    p1 : tuple
        point 1 with x, y, z coordinates
    p2 : tuple
        point 2 with x, y, z coordinates
    p3 : tuple
        point 3 with x, y, z coordinates

    Returns
    -----
    curvature : float
        rate of change in direction with respect to distance along the curve
    """

    # Convert points to numpy arrays for easier vector operations
    p1, p2, p3 = np.array(p1), np.array(p2), np.array(p3)

    # Compute the area of the triangle formed by P1, P2, P3
    triangle_area = 0.5 * np.linalg.norm(np.cross(p2 - p1, p3 - p1))

    # Compute the distances between the points
    d12 = np.linalg.norm(p2 - p1)
    d23 = np.linalg.norm(p3 - p2)
    d13 = np.linalg.norm(p3 - p1)

    # Calculate Menger curvature
    curvature = 0.0
    if d12 * d23 * d13 > 0.0:
        curvature = 4 * triangle_area / (d12 * d23 * d13)
    
    return curvature


def get_stroke_curvature(df, trial_num, hand):
    """
    Gets the curvature of a single stroke/trial.
    
    Parameters
    -----
    df : dataframe
        file dataframe to analyze
    trial_num : int
        trial number or gesture counter UI to analyze
    hand : char
        left or right controller to analyze the position/translation

    Returns
    -----
    curvature_avg : float
        the sum of all the external angles divided by the number of angles added to that sum
    """
    # Filter DataFrame for the specified trial number and non-zero trigger pull
    trigger_col = f"trigger_pull_amount_{'left' if hand == 'l' else 'right'}"
    condition = (df[trigger_col] != 0) & (df['gesture_counter_UI'] == trial_num)
    condition &= df[hand + "_controller_translation_x"].notna()
    filtered_df = df[condition].reset_index(drop=True)

    # Smooths the curve
    x = np.array(filtered_df[hand + '_controller_translation_x'])
    y = np.array(filtered_df[hand + '_controller_translation_y'])
    z = np.array(filtered_df[hand + '_controller_translation_z'])

    # The number of control points and knots
    k = 3  # degree of the B-spline
    t = np.linspace(0, 1, len(filtered_df))
    # Create the B-spline representation for each dimension
    # Condition checks that make_interp_spline will return valid values
    if (len(t) > 0) and (len(x) > 3):
        spl_x = make_interp_spline(t, x, k=k)
        spl_y = make_interp_spline(t, y, k=k)
        spl_z = make_interp_spline(t, z, k=k)
        # Evaluate the B-spline over a dense set of points for a smooth trajectory
        dense_t = np.linspace(0, 1, 5 * len(filtered_df))  # points in the smoothed curve; can be adjusted
        x_smooth = spl_x(dense_t)
        y_smooth = spl_y(dense_t)
        z_smooth = spl_z(dense_t)
        coordinates = list(zip(x_smooth, y_smooth, z_smooth))

        # Determine the new data points based on min distance
        n_points_desired = 10
        points_list = []
        min_points_distance = round(len(x_smooth) / (n_points_desired))
        for coordinate in coordinates[::min_points_distance]:
            points_list.append(coordinate)

        # Get a list of curvatures from points list
        curvature_list = []
        for index in range(2, len(points_list)):
            curvature_list.append(calculate_curvature(points_list[index-2], points_list[index-1], points_list[index]))

        # Remove extreme curvatures
        curvature_list = remove_extremities(curvature_list)

        # Calculate avg curvature
        return sum(curvature_list)/len(curvature_list)


def normalize_coordinates(coordinates):
    min_x, max_x = min(coordinates, key=lambda p: p[0])[0], max(coordinates, key=lambda p: p[0])[0]
    min_y, max_y = min(coordinates, key=lambda p: p[1])[1], max(coordinates, key=lambda p: p[1])[1]
    min_z, max_z = min(coordinates, key=lambda p: p[2])[2], max(coordinates, key=lambda p: p[2])[2]


    normalize_coordinates = []
    for x, y, z in coordinates:
        normalize_coordinates.append(
            ((x-min_x)/(max_x-min_x),
             (y-min_y)/(max_y-min_y),
             (z-min_z)/(max_z-min_z)
             )
        )

    return normalize_coordinates

# %% [markdown]
# ### Overview #11
# Helper methods to apply metric calculations to the data files.
#
# ### Functions
# * apply_duration_calc: Only used for the duration calculations
# * apply_kinematic_calc: Only used for the speed or acceleration calculations.
# * apply_geometric_calc: Only used for length, angle, or curvature calculations.

# %%
def apply_duration_calc(duration_folder):
   """
   Calculates and exports the duration of each gesture session into CSV files.

   Parameters
   -----
   duration_folder : str
        The folder where the output duration CSV files will be stored.
   """

   for index, gesture in enumerate(gesture_dict):
        for index2, session_type in enumerate(gesture_dict[gesture]):
            output_path = get_gest_export_path(duration_folder, session_type[0], gesture, 'duration')
            column_name = get_column_name(session_type[0], gesture)

            data_points_list = []
            
            # Iterates through each file and adds all of its trial data its respective list
            for file_num in range(len(session_type)):
                file_df = pd.read_csv(session_type[file_num])
                # Remove strokes in freeform
                if index2 == 0:
                    remove_strokes(file_df, index, file_num)
                num_trials = 5
                if len(file_df.index) > 2:
                    for trial_num in range(num_trials):
                        data_points_list.append(get_stroke_duration(file_df, trial_num+1))
                    data_points_list.append(np.nan)
            
            # Export single gesture session data to a CSV
            single_gesture_session_df = pd.DataFrame({column_name: data_points_list})
            if not os.path.exists(output_path):
                single_gesture_session_df.to_csv(output_path, header=True, index=False)



def apply_kinematic_calc(func, duration_folder, other_folder, output_folder, metric_name):
    """
    Applies a kinematic calculation (speed or acceleration) to corresponding data files and exports the results.

    Parameters
    -----
    func : callable
        A function that takes two arguments, data values from the duration and other folder, and returns a calculated metric.
    duration_folder : str
        Path to the folder containing duration CSV files.
    other_folder : str
        Path to the folder containing the other metric CSV files. Length for speed calculation or speed for acceleration calculation.
    output_folder : str
        Path to the folder where the output CSV files will be saved.
    metric_name : str
        The name of the calculated metric (e.g., "speed", "acceleration").
    """

    # List of files in each folder directory
    duration_files = sorted(os.listdir(duration_folder))
    other_files = sorted(os.listdir(other_folder))      

    for file_num, other_file in enumerate(other_files):
        duration_df = pd.read_csv(os.path.join(duration_folder, duration_files[file_num]), skip_blank_lines=False)
        other_df = pd.read_csv(os.path.join(other_folder, other_file), skip_blank_lines=False)
        single_gesture_session_df = pd.DataFrame()

        # Construct output file path
        output_path = os.path.join(output_folder, f"{metric_name}_for_" + '_'.join(other_file.split('_')[2:]))

        # Iterates through each of the column in the other dataframe
        for col_num in range(len(other_df.columns)):
            column_name = other_df.columns[col_num]
            data_points_list = []

            # Calculates the metric and adds it to the dataframe
            for row_num in range(len(other_df)):
                other = (other_df.iloc[row_num][other_df.columns[col_num]])
                duration = (duration_df.iloc[row_num][duration_df.columns[int(col_num/2)]])
                if (other == np.nan) or (duration == np.nan):
                    data_points_list.append(np.nan)
                else:
                    data_points_list.append(func(other, duration))

            single_gesture_session_df[column_name] = data_points_list
        
        # Save the output CSV if it doesn't already exist
        if not os.path.exists(output_path):
            single_gesture_session_df.to_csv(output_path, header=True, index=False)



def apply_geometric_calc(func, output_folder_path, metric_name):
    """
    Applies a geometric calculation (length, external angle, curvature) to strokes.

    Parameters
    -----
    output_folder_path : str
        The folder path where the output CSV files will be saved.
    metric_name : str
        The metric to be calculated for each gesture.
    func : callable
        A function to calculate the metric for each trial.
    """

    for index, gesture in enumerate(gesture_dict):
        for index2, session_type in enumerate(gesture_dict[gesture]):
            output_path =  get_gest_export_path(output_folder_path, session_type[0], gesture, metric_name)
            column_name = get_column_name(session_type[0], gesture)
            
            # Lists to hold data points for left and right hands
            data_points_left_list = []
            data_points_right_list = []
            
            # Process each file in session type
            for file_num in range(len(session_type)):
                file_df = pd.read_csv(session_type[file_num])

                # Remove strokes in based on strokes_to_remove.csv
                if index2 == 0:
                    remove_strokes(file_df, index, file_num)
                
                # Calculate data points for each trial and append to list
                if len(file_df.index) > 2:
                    data_points_right_list.extend(func(file_df, trial_num + 1, 'r') for trial_num in range(5))
                    data_points_left_list.extend(func(file_df, trial_num + 1, 'l') for trial_num in range(5))

                # Separate data files with NaN for readability in CSV
                data_points_left_list.append(np.nan)
                data_points_right_list.append(np.nan)

            # Export the gesture session data to CSV
            single_gesture_session_df = pd.DataFrame({
                f"{column_name} (Left)": data_points_left_list,
                f"{column_name} (Right)": data_points_right_list
            })
            
            if not os.path.exists(output_path):
                single_gesture_session_df.to_csv(output_path, header=True, index=False)

# %% [markdown]
# ### Overview #12
# Run all metric calculations here.
#
# ### Variables
# * length_folder_path
# * duration_folder_path
# * speed_folder_path
# * acceleration_folder_path
# * angle_folder_path
# * curvature_folder_path
#
# ### To Do
# * Edit variable paths.
# * Uncomment the functions to run. Must run in the following order.

# %%
length_folder_path = '..\\VRelax\\gestureInterface\\MetricCalculations\\GestureLength'
duration_folder_path = '..\\VRelax\\gestureInterface\\MetricCalculations\\GestureDuration'
speed_folder_path = '..\\VRelax\\gestureInterface\\MetricCalculations\\GestureSpeed'
acceleration_folder_path = '..\\VRelax\\gestureInterface\\MetricCalculations\\GestureAcceleration'
angle_folder_path = '..\\VRelax\\gestureInterface\\MetricCalculations\\GestureAngle'
curvature_folder_path = '..\\VRelax\\gestureInterface\\MetricCalculations\\GestureCurvature'

#apply_geometric_calc(get_stroke_length, length_folder_path, 'length')
#apply_duration_calc(duration_folder_path)
#apply_kinematic_calc(calculate_speed, duration_folder_path, length_folder_path, speed_folder_path, 'speed')
#apply_kinematic_calc(calculate_acceleration, duration_folder_path, speed_folder_path, acceleration_folder_path, 'acceleration')
#apply_geometric_calc(get_stroke_angle, angle_folder_path, 'angle')
#apply_geometric_calc(get_stroke_curvature, curvature_folder_path, 'curvature')
